# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.image as image
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms
import seaborn as sns
plt.rc('figure', facecolor='w')
plt.rc('font', size=11)

# %%
df = pd.read_fwf('data/features_full_dhfr.dat', widths=(6,9,) + (13,) * 44)
LAST_CLOSED = len(df) // 2
BLOCK = len(df) // 2

# %%
ang_column_map = {f'{ang}:{i}':f'{ang}_{i}' 
                  for ang in ('phi', 'psi') for i in range(10,31)}
df.rename(columns=ang_column_map, inplace=True)

# %%
def block_to_continuous(block):
    result = block[:1]
    ref = result[0]
    ref = 1000
    for value in block:
        if abs(value) < ref:
            ref = value
    for value in block[1:]:
        diff = value - ref
        result.append(value - 360 * round(diff / 360))
    return result

def block_to_continuous(block):
    data = np.array(block)
    max_density_value = np.mean(data)
    return list(data - 360 * np.round((data - max_density_value) / 360))
    

def ang_to_continuous(values):
    result = []
    for i in range(len(values) // BLOCK):
        result.extend(block_to_continuous(values[BLOCK * i: BLOCK * (i+1)]))
    return result

# %%
for column in df.columns[5:]:
    df[column] = ang_to_continuous(list(df[column]))

# %%
df_closed = df.iloc[:LAST_CLOSED,:]
df_open = df.iloc[LAST_CLOSED:,:]

# %%
all_cols = list(df.columns)
fig1_cols = all_cols[4:] + all_cols[2:4]

# %%
flat_df = df.melt(id_vars='state', value_vars=fig1_cols)
flat_df_deg = df.melt(id_vars='state', value_vars=fig1_cols[:-14])
flat_df_dist = df.melt(id_vars='state', value_vars=fig1_cols[-2:])

# %%
patch_color = '#FFFFCC'
grid_color = '#AAAAAA'

# %%
PALETTE = ['blue', 'red']

def plot_fig2(ax):
    
    sns.violinplot(x='variable', y='value', hue='state', data=flat_df_deg, split=True, 
                   inner=None, ax=ax, cut=0, palette=PALETTE, linewidth=0.)
    ax.get_legend().remove()


    patch = mpl.patches.Rectangle((13.5, -180), 3, 360, 
                                  facecolor=patch_color, 
                                  lw=0, clip_on=False, zorder=-1)
    ax.add_patch(patch)

    labels = [f'${ang}_{{{i}}}$' for i in range(10, 25) for ang in ('\Phi', '\Psi') ] + ['$d_1$', '$d_2$']
    ax.set_xlim(-0.5, len(labels) - 0.5)
    ax.set_xticks(range(len(labels)))
    ax.set_xticklabels(labels)
    ax.set_xlabel(None)
    ax.set_ylabel('Angle ($\degree$)', labelpad=-5)
    ax.set_ylim((-180, 180))
    ax.set_yticks((-180, -90, 0, 90, 180))
    
    for i in range(1, len(labels), 2):
        ax.axvline(i+0.5, -180, 180, c=grid_color, lw=0.5)
    ax.set_axisbelow(True)
    
    ax2 = ax.twinx()
    sns.violinplot(x='variable', y='value', hue='state', data=flat_df_dist, split=True, inner=None, ax=ax2, 
                   cut=0, palette=PALETTE, linewidth=0., order=labels[:-2] + ['d1', 'd2'])
    ax2.get_legend().remove()        

    ax2.set_xticklabels(labels)
    ax2.set_ylabel('Distance ($\AA$)', labelpad=0)
    ax2.set_ylim((2, 18))
    ax2.set_yticks((2, 6, 10, 14, 18))    
    
    ax.axvline(23.5, -180, 180, c='black', lw=1.0)


sns.reset_orig()
fig, axs = plt.subplot_mosaic([['a', 'a'], ['b', 'c']], figsize=(10,6), gridspec_kw={'wspace': 0})
fig.tight_layout()
plot_fig2(axs['a'])
for ax, img_filename in zip((axs['b'], axs['c']), ('S8b.png', 'S8c.png')):
    ax.set_xticks([])
    ax.set_yticks([])
    img = image.imread(f'data/{img_filename}')
    ax.imshow(img)
axs['b'].set_position([0.0455, -0.135, 0.455, 1])
axs['c'].set_position([0.52, -0.4, 0.455, 1])

for label, ax in axs.items():
    trans = mtransforms.ScaledTranslation(10/72, -5/72, fig.dpi_scale_trans)
    ax.text(-0.01, 1.0, label, transform=ax.transAxes + trans, 
            verticalalignment='top', fontsize='large')
plt.savefig('FigS8.png', dpi=300, bbox_inches='tight')
plt.show()
